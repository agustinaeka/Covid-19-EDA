# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv("covid-nationality.csv")

# %%
df.head()
# Out:
#    Unnamed: 0                 date state  hospitalized_with_symptoms  \
# 0           0  2020-02-24T18:00:00   ITA                         101
# 1           1  2020-02-25T18:00:00   ITA                         114
# 2           2  2020-02-26T18:00:00   ITA                         128
# 3           3  2020-02-27T18:00:00   ITA                         248
# 4           4  2020-02-28T18:00:00   ITA                         345
#
#    intensive_care  total_hospitalized  home_quarantine  total_confirmed_cases  \
# 0              26                 127               94                    221
# 1              35                 150              162                    311
# 2              36                 164              221                    385
# 3              56                 304              284                    588
# 4              64                 409              412                    821
#
#    variation_total_confirmed  new_confirmed_cases  recovered  deaths  \
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'date', 'state', 'hospitalized_with_symptoms',
#        'intensive_care', 'total_hospitalized', 'home_quarantine',
#        'total_confirmed_cases', 'variation_total_confirmed',
#        'new_confirmed_cases', 'recovered', 'deaths', 'total_cases',
#        'swabs_made', 'casi_testati', 'note_it', 'note_en'],
#       dtype='object')

# %%
df.describe()
# Out:
#        Unnamed: 0  hospitalized_with_symptoms  intensive_care  \
# count   70.000000                   70.000000       70.000000
# mean    34.500000                17373.142857     2225.128571
# std     20.351085                10475.956363     1330.399743
# min      0.000000                  101.000000       26.000000
# 25%     17.250000                 6844.000000     1196.750000
# 50%     34.500000                20522.500000     2325.500000
# 75%     51.750000                27262.750000     3392.250000
# max     69.000000                29010.000000     4068.000000
#
#        total_hospitalized  home_quarantine  total_confirmed_cases  \
# count           70.000000        70.000000              70.000000
# mean         19598.285714     41387.885714           60986.157143
# std          11743.460668     32774.474616           42510.504183
# min            127.000000        94.000000             221.000000
# 25%           8040.750000      5327.250000           13368.000000
# ...

# %%
df.shape
# Out:
# (70, 17)

# %%
df.nunique()
# Out:
# Unnamed: 0                    70
# date                          70
# state                          1
# hospitalized_with_symptoms    70
# intensive_care                70
# total_hospitalized            70
# home_quarantine               70
# total_confirmed_cases         70
# variation_total_confirmed     69
# new_confirmed_cases           70
# recovered                     69
# deaths                        70
# total_cases                   70
# swabs_made                    70
# casi_testati                  15
# note_it                       18
# note_en                       18
# dtype: int64

# %%
df['recovered'].unique()
# Out:
# array([    1,     3,    45,    46,    50,    83,   149,   160,   276,
#          414,   523,   589,   622,   724,  1004,  1045,  1258,  1439,
#         1966,  2335,  2749,  2941,  4025,  4440,  5129,  6072,  7024,
#         7432,  8326,  9362, 10361, 10950, 12384, 13030, 14620, 15729,
#        16847, 18278, 19758, 20996, 21815, 22837, 24392, 26491, 28470,
#        30455, 32534, 34211, 35435, 37130, 38092, 40164, 42727, 44927,
#        47055, 48877, 51600, 54543, 57576, 60498, 63120, 64928, 66624,
#        68941, 71252, 75945, 78249, 79914, 81654])

# %%
df['total_hospitalized'].unique()
# Out:
# array([  127,   150,   164,   304,   409,   506,   779,   908,  1263,
#         1641,  2141,  2856,  3218,  4207,  5049,  5915,  6866,  7803,
#         8754,  9890, 11335, 12876, 14954, 16620, 18255, 18675, 20565,
#        22855, 23896, 25333, 26601, 28365, 29761, 30532, 31292, 31776,
#        32215, 32438, 32593, 32809, 33004, 32926, 32874, 32510, 32178,
#        32004, 31739, 31525, 31190, 31283, 31197, 30722, 29829, 28598,
#        27740, 27668, 27479, 26605, 26189, 25138, 24241, 23635, 23381,
#        22309, 21586, 21005, 19843, 19147, 18896, 18743])

# %%
#cleaning data!

# %%
df.isna().sum()
# Out:
# Unnamed: 0                     0
# date                           0
# state                          0
# hospitalized_with_symptoms     0
# intensive_care                 0
# total_hospitalized             0
# home_quarantine                0
# total_confirmed_cases          0
# variation_total_confirmed      0
# new_confirmed_cases            0
# recovered                      0
# deaths                         0
# total_cases                    0
# swabs_made                     0
# casi_testati                  55
# note_it                       52
# note_en                       52
# dtype: int64

# %%
df.head(8)
# Out:
#    Unnamed: 0                 date state  hospitalized_with_symptoms  \
# 0           0  2020-02-24T18:00:00   ITA                         101
# 1           1  2020-02-25T18:00:00   ITA                         114
# 2           2  2020-02-26T18:00:00   ITA                         128
# 3           3  2020-02-27T18:00:00   ITA                         248
# 4           4  2020-02-28T18:00:00   ITA                         345
# 5           5  2020-02-29T18:00:00   ITA                         401
# 6           6  2020-03-01T18:00:00   ITA                         639
# 7           7  2020-03-02T18:00:00   ITA                         742
#
#    intensive_care  total_hospitalized  home_quarantine  total_confirmed_cases  \
# 0              26                 127               94                    221
# 1              35                 150              162                    311
# 2              36                 164              221                    385
# ...

# %%
df.tail()
# Out:
#     Unnamed: 0                 date state  hospitalized_with_symptoms  \
# 65          65  2020-04-29T17:00:00   ITA                       19210
# 66          66  2020-04-30T17:00:00   ITA                       18149
# 67          67  2020-05-01T17:00:00   ITA                       17569
# 68          68  2020-05-02T17:00:00   ITA                       17357
# 69          69  2020-05-03T17:00:00   ITA                       17242
#
#     intensive_care  total_hospitalized  home_quarantine  \
# 65            1795               21005            83652
# 66            1694               19843            81708
# 67            1578               19147            81796
# 68            1539               18896            81808
# 69            1501               18743            81436
#
#     total_confirmed_cases  variation_total_confirmed  new_confirmed_cases  \
# 65                 104657                       -548                 2086
# ...

# %%
#drop all column with null values
df = df.dropna(axis=1)

# %%
df
# Out:
#     Unnamed: 0                 date state  hospitalized_with_symptoms  \
# 0            0  2020-02-24T18:00:00   ITA                         101
# 1            1  2020-02-25T18:00:00   ITA                         114
# 2            2  2020-02-26T18:00:00   ITA                         128
# 3            3  2020-02-27T18:00:00   ITA                         248
# 4            4  2020-02-28T18:00:00   ITA                         345
# ..         ...                  ...   ...                         ...
# 65          65  2020-04-29T17:00:00   ITA                       19210
# 66          66  2020-04-30T17:00:00   ITA                       18149
# 67          67  2020-05-01T17:00:00   ITA                       17569
# 68          68  2020-05-02T17:00:00   ITA                       17357
# 69          69  2020-05-03T17:00:00   ITA                       17242
#
#     intensive_care  total_hospitalized  home_quarantine  \
# 0               26                 127               94
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                    0
# date                          0
# state                         0
# hospitalized_with_symptoms    0
# intensive_care                0
# total_hospitalized            0
# home_quarantine               0
# total_confirmed_cases         0
# variation_total_confirmed     0
# new_confirmed_cases           0
# recovered                     0
# deaths                        0
# total_cases                   0
# swabs_made                    0
# dtype: int64

# %%
# relationship analysis

# %%
corelation = df.corr()

# %%
corelation
# Out:
#                             Unnamed: 0  hospitalized_with_symptoms  \
# Unnamed: 0                    1.000000                    0.759971
# hospitalized_with_symptoms    0.759971                    1.000000
# intensive_care                0.536125                    0.946883
# total_hospitalized            0.738680                    0.999336
# home_quarantine               0.977207                    0.795108
# total_confirmed_cases         0.957461                    0.889073
# variation_total_confirmed    -0.305721                    0.227592
# new_confirmed_cases           0.289439                    0.722996
# recovered                     0.937960                    0.509869
# deaths                        0.981392                    0.718915
# total_cases                   0.988393                    0.770240
# swabs_made                    0.955030                    0.555912
#
#                             intensive_care  total_hospitalized  \
# ...

# %%
sns.heatmap(corelation)
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(df)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'date', 'state', 'hospitalized_with_symptoms',
#        'intensive_care', 'total_hospitalized', 'home_quarantine',
#        'total_confirmed_cases', 'variation_total_confirmed',
#        'new_confirmed_cases', 'recovered', 'deaths', 'total_cases',
#        'swabs_made'],
#       dtype='object')

# %%
sns.relplot(x="total_cases", y="deaths", hue="recovered", data=df)

# %%
sns.distplot(df['recovered'], bins=10)
plt.xticks(rotation="vertical")

plt.show()
# Out:
# /home/eka/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.catplot(x="total_confirmed_cases", y="recovered", kind="box", data=df)
